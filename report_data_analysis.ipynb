# %%
import altair as alt
import pandas as pd
import glob
alt.data_transformers.enable('json')
# Out:
# DataTransformerRegistry.enable('json')

# %%
files = glob.glob(r'C:\Users\mitch\Desktop\Masters\VisualAnalytics\2018MiniChallenge\purchase_communication_results\*layer_1.csv')
len(files)
# Out:
# 8

# %%
def plot_data(my_data):
    interval = alt.selection_interval(encodings=['x'])
    my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
    purchase_row = my_data.loc[my_data['Etype'] == 'original purchase'].iloc[0]
    chart1 = alt.Chart(my_data).mark_point().encode(
        alt.X('month_day_yr:T', timeUnit='yearmonthdatehours', axis=alt.Axis(title='Month Date Year')),
        y='Etype:N',
        color=alt.condition(interval,'Etype:N',alt.value('lightgray')),
        tooltip=['Source_Names','Destination_Names', 'month_day_yr:T']
    ).interactive().properties(selection=interval, title = 'Source {} Dest {} Time {}'.format(
    purchase_row['Source_Names'],
    purchase_row['Destination_Names'],
    purchase_row['month_day_yr']
    ))

    chart2 = alt.Chart(my_data).mark_point().encode(
        alt.X('month_day_yr:T', timeUnit='yearmonthdatehours', axis=alt.Axis(title='Month Date Year')),
        y='Etype:N',
        color=alt.condition(interval,'Etype:N',alt.value('lightgray')),
        tooltip=['Source_Names','Destination_Names', 'month_day_yr:T']
    ).interactive().transform_filter(interval)


    hist = alt.Chart(my_data).mark_bar().encode(
        y='Etype:N',
        x='count()',
        color='Etype:N'
    ).transform_filter(
        interval
    )

    return (chart1 | chart2) & hist

# %%
my_data = pd.read_csv(files[0])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
my_data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1   Source   Etype  Destination   TimeStamp  \
# 0    24859522     7868322.0  1847246   calls       728286  1493401133
# 1    24859523     7890047.0  1847246   calls       728286  1493573933
# 2    24859524     9411368.0  1847246   calls       728286  1505373223
# 3    24859525    12962751.0  1847246  emails       728286  1505673223
# 4    24859526     9471795.0  1847246   calls       728286  1505842733
#
#              full_date month_day_yr month_yr  month    yr      Source_Names  \
# 0  2017-04-28 17:38:53   04/28/2017  04/2017      4  2017  Rosalia Larroque
# 1  2017-04-30 17:38:53   04/30/2017  04/2017      4  2017  Rosalia Larroque
# 2  2017-09-14 07:13:43   09/14/2017  09/2017      9  2017  Rosalia Larroque
# 3  2017-09-17 18:33:43   09/17/2017  09/2017      9  2017  Rosalia Larroque
# 4  2017-09-19 17:38:53   09/19/2017  09/2017      9  2017  Rosalia Larroque
#
#   Destination_Names
# 0   Kerstin Belveal
# 1   Kerstin Belveal
# 2   Kerstin Belveal
# ...

# %%
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files[1])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files[2])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files[3])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files[4])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files[5])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files[6])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files[7])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
files_layer2 = glob.glob(r'C:\Users\mitch\Desktop\Masters\VisualAnalytics\2018MiniChallenge\purchase_communication_results\*layer_2.csv')

# %%
my_data = pd.read_csv(files_layer2[0])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files_layer2[1])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files_layer2[2])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files_layer2[3])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files_layer2[4])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files_layer2[5])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files_layer2[6])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files_layer2[7])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
files_layer3 = glob.glob(r'C:\Users\mitch\Desktop\Masters\VisualAnalytics\2018MiniChallenge\purchase_communication_results\*layer_3.csv')

# %%
my_data = pd.read_csv(files_layer3[0])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files_layer3[1])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files_layer3[2])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files_layer3[3])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files_layer3[4])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files_layer3[5])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files_layer3[6])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data = pd.read_csv(files_layer3[7])
my_data['Etype'].replace({0:'calls',1:'emails',2:'purchases',3:'meetings',5:'original purchase'}, inplace=True)
plots = plot_data(my_data)
plots
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
purch_analysis = pd.read_csv(r'C:\Users\mitch\Desktop\Masters\VisualAnalytics\2018MiniChallenge\purchase_communication_results\deep_purchase_analysis_result_df.csv')

# %%
purch_analysis.columns
# Out:
# Index(['Unnamed: 0', 'meeting_count', 'found_unique_meeting_repeat', 'Source',
#        'Destination', 'Source_Names', 'Destination_Names',
#        'Primary_source_interactions', 'Primary_dest_interactions',
#        'Avg_dest_count', 'Avg_source_count', 'num_uniq_source',
#        'num_uniq_dest', 'combined_unique', 'total_entries',
#        'suspicious_indicator', 'mean_time_btwn', 'max_time_btwn',
#        'min_time_btwn', 'mean_rolling_diff', 'max_rolling_diff',
#        'min_rolling_diff', 'mean_rolling_window', 'max_rolling_window',
#        'min_rolling_window'],
#       dtype='object')

# %%
alt.Chart(purch_analysis).mark_bar().encode(
    y='Source_Names',
    x='Primary_source_interactions',
    color='Source_Names'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(purch_analysis).mark_bar().encode(
    y='Source_Names',
    x='Avg_dest_count',
    color='Source_Names'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(purch_analysis).mark_bar().encode(
    y='Source_Names',
    x='Avg_source_count',
    color='Source_Names'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(purch_analysis).mark_bar().encode(
    y='Source_Names',
    x='num_uniq_source',
    color='Source_Names'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(purch_analysis).mark_bar().encode(
    y='Source_Names',
    x='num_uniq_dest',
    color='Source_Names'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
purch_analysis.columns
# Out:
# Index(['Unnamed: 0', 'meeting_count', 'found_unique_meeting_repeat', 'Source',
#        'Destination', 'Source_Names', 'Destination_Names',
#        'Primary_source_interactions', 'Primary_dest_interactions',
#        'Avg_dest_count', 'Avg_source_count', 'num_uniq_source',
#        'num_uniq_dest', 'combined_unique', 'total_entries',
#        'suspicious_indicator', 'mean_time_btwn', 'max_time_btwn',
#        'min_time_btwn', 'mean_rolling_diff', 'max_rolling_diff',
#        'min_rolling_diff', 'mean_rolling_window', 'max_rolling_window',
#        'min_rolling_window'],
#       dtype='object')

# %%
alt.Chart(purch_analysis).mark_bar().encode(
    y='Source_Names',
    x='combined_unique',
    color='Source_Names'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(purch_analysis).mark_bar().encode(
    y='Source_Names',
    x='total_entries',
    color='Source_Names'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(purch_analysis).mark_bar().encode(
    y='Source_Names',
    x='mean_time_btwn',
    color='Source_Names'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(purch_analysis).mark_bar().encode(
    y='Source_Names',
    x='max_time_btwn',
    color='Source_Names'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(purch_analysis).mark_bar().encode(
    y='Source_Names',
    x='mean_rolling_diff',
    color='Source_Names'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(purch_analysis).mark_bar().encode(
    y='Source_Names',
    x='max_rolling_diff',
    color='Source_Names'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
interval = alt.selection_single()
alt.Chart(purch_analysis).mark_rect().encode(
    y='Source_Names',
    x='min_rolling_diff',
    color=alt.condition(interval,'Source_Names',alt.value('lightgray'))
).properties(selection=interval).interactive()
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(purch_analysis).mark_bar().encode(
    y='Source_Names',
    x='mean_rolling_window',
    color='Source_Names'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(purch_analysis).mark_bar().encode(
    y='Source_Names',
    x='max_rolling_window',
    color='Source_Names'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(purch_analysis).mark_bar().encode(
    y='Source_Names',
    x='min_rolling_window',
    color='Source_Names'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
