# %%
import altair as alt
import pandas as pd

##Interesting observation, the company seems to plumet in terms of business performed ~ 5 months before suspicous data
##begins

# %%
my_data = pd.read_csv('data_described_frequency_v2.csv')

# %%
my_data.head()
# Out:
#    Unnamed: 0  avg_time_between_interactions  change_in_unique_dest  \
# 0          40                       6.440824                   29.0
# 1          72                     114.981942                   25.0
# 2         104                  104736.000000                    5.0
# 3           8                       8.785978                  133.0
# 4          75                     111.327434                   34.0
#
#    change_in_unique_source  data_amount  data_type month_yr  num_unique_dest  \
# 0                     41.0     278795.0     emails  05/2015          10491.0
# 1                   2448.0      15617.0  purchases  05/2015             63.0
# 2                     13.0         15.0   meetings  05/2015              5.0
# 3                    152.0     204382.0      calls  05/2015          10658.0
# 4                   7138.0      23282.0  purchases  06/2015             72.0
#
#    num_unique_source   date_time
# 0            10769.0  2015-05-01
# 1             4834.0  2015-05-01
# 2               14.0  2015-05-01
# 3            10728.0  2015-05-01
# 4            10772.0  2015-06-01

# %%
call_data = my_data[my_data['data_type'] == 'calls']
alt.Chart(call_data).mark_point().encode(
    x ='date_time:T',
    y='avg_time_between_interactions',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
mtg_data = my_data[my_data['data_type'] == 'meetings']
alt.Chart(mtg_data).mark_point().encode(
    x ='date_time:T',
    y='avg_time_between_interactions',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
email_data = my_data[my_data['data_type'] == 'emails']
alt.Chart(email_data).mark_point().encode(
    x ='date_time:T',
    y='avg_time_between_interactions',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
purchase_data = my_data[my_data['data_type'] == 'purchases']
alt.Chart(purchase_data).mark_point().encode(
    x ='date_time:T',
    y='avg_time_between_interactions',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
all_but_mtg = my_data[my_data['data_type'] != 'meetings']
alt.Chart(all_but_mtg).mark_point().encode(
    x ='date_time:T',
    y='avg_time_between_interactions',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
my_data.head()
# Out:
#    Unnamed: 0  avg_time_between_interactions  change_in_unique_dest  \
# 0           0                       7.879802               108196.0
# 1           1                       7.781122                92219.0
# 2           2                       7.852428                39486.0
# 3           3                       7.747055                87981.0
# 4           4                       7.841911                49733.0
#
#    change_in_unique_source  data_amount data_type month_yr  num_unique_dest  \
# 0                 107840.0     339906.0     calls  01/2016         108196.0
# 1                  92276.0     344216.0     calls  01/2017         163879.0
# 2                  39632.0     319085.0     calls  02/2016         111381.0
# 3                  87577.0     312271.0     calls  02/2017         156413.0
# 4                  49988.0     341550.0     calls  03/2016         121845.0
#
#    num_unique_source
# 0           107840.0
# 1           163455.0
# 2           111116.0
# 3           155403.0
# 4           121311.0

# %%
alt.Chart(my_data).mark_point().encode(
    x ='date_time:T',
    y='change_in_unique_dest',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(my_data).mark_point().encode(
    x ='date_time:T',
    y='change_in_unique_source',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(my_data).mark_point().encode(
    x ='date_time:T',
    y='data_amount',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(my_data).mark_point().encode(
    x ='date_time:T',
    y='num_unique_dest',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(my_data).mark_point().encode(
    x ='date_time:T',
    y='num_unique_source',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(my_data).mark_bar().encode(
    x ='date_time:T',
    y='num_unique_source',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(my_data).mark_bar().encode(
    x ='date_time:T',
    y='num_unique_dest',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
only_purchases = my_data[my_data['data_type']=='purchases']
alt.Chart(only_purchases).mark_bar().encode(
    x ='date_time:T',
    y='num_unique_source',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(only_purchases).mark_bar().encode(
    x ='date_time:T',
    y='num_unique_dest',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(only_purchases).mark_bar().encode(
    x ='date_time:T',
    y='change_in_unique_source',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(only_purchases).mark_bar().encode(
    x ='date_time:T',
    y='change_in_unique_dest',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
purchases_data = pd.read_csv('purchases_described_comparing_gail.csv')

# %%
purchases_data.head()
# Out:
#    Unnamed: 0  avg_time_between_interactions  change_in_unique_dest  \
# 0           8                     117.656641                      0
# 1          40                    5039.025424                     25
# 2          11                     113.963416                      0
# 3          43                    4321.184015                     34
# 4          14                     114.378587                      0
#
#    change_in_unique_source  data_amount data_type month_yr  num_unique_dest  \
# 0                     2447        15262      gail  05/2015                1
# 1                      272          355   no_gail  05/2015               62
# 2                     7094        22743      gail  06/2015                1
# 3                      459          539   no_gail  06/2015               71
# 4                     9831        23417      gail  07/2015                1
#
#    num_unique_source   date_time
# 0               4781  2015-05-01
# 1                299  2015-05-01
# 2              10636  2015-06-01
# 3                485  2015-06-01
# 4              13409  2015-07-01

# %%
alt.Chart(purchases_data).mark_point().encode(
    x='date_time:T',
    y='avg_time_between_interactions',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(purchases_data).mark_point().encode(
    x='date_time:T',
    y='change_in_unique_dest',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(purchases_data).mark_point().encode(
    x='date_time:T',
    y='change_in_unique_source',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(purchases_data).mark_point().encode(
    x='date_time:T',
    y='data_amount',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(purchases_data).mark_bar().encode(
    x='date_time:T',
    y='avg_time_between_interactions',
    color='data_type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
